# %% [markdown]
# ### Cuando se use colab

# %%
#import sys
#import os

#py_file_location = "/content/TensorFlow-Advanced-Segmentation-Models"
#sys.path.append(os.path.abspath(py_file_location))

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
#!pip install -U albumentations>=3.0.0
#!git clone https://github.com/JanMarcelKezmann/TensorFlow-Advanced-Segmentation-Models

# %% [markdown]
# ### Desarrollo

# %%
import tensorflow_advanced_segmentation_models as tasm
import os
import cv2
import numpy as np
from time import time
import tensorflow as tf
import albumentations as A
import matplotlib.pyplot as plt
import tensorflow.keras.backend as K

# %%
#Personal pc
#main_path = "C:/Users/SEBASTIAN/OneDrive - Universidad de los Andes/OctavoSemestre/Robocol_vision/Img/prueba_segmentacion/"
#Colab
#main_path = "/content/drive/MyDrive/TresClases_Ordenado/"
#Super pc universidad
main_path = "C:/Users/Imagine/Documents/Robocol_vision/TresClases_Ordenado/"

x_train_dir = main_path + 'train/x_aug/'
y_train_dir = main_path + 'train/y_aug/'
x_valid_dir = main_path + 'val/x_aug/'
y_valid_dir = main_path + 'val/y_aug/'
x_test_dir = main_path + 'test/x_aug/'
y_test_dir = main_path + 'test/y_aug/'

# %% [markdown]
# ### Helper functions

# %%
# helper function for data visualization
def visualize(**images):
    """PLot images in one row."""
    n = len(images)
    plt.figure(figsize=(16, 5))
    for i, (name, image) in enumerate(images.items()):
        plt.subplot(1, n, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.title(' '.join(name.split('_')).title())
        plt.imshow(image)
    plt.show()
    
# helper function for data visualization    
def denormalize(x):
    """Scale image to range 0..1 for correct plot"""
    x_max = np.percentile(x, 98)
    x_min = np.percentile(x, 2)    
    x = (x - x_min) / (x_max - x_min)
    x = x.clip(0, 1)
    return x
    
def round_clip_0_1(x, **kwargs):
    return x.round().clip(0, 1)

# %% [markdown]
# ### Data augmentation functions

# %%
# define heavy augmentations
def get_training_augmentation(height, width):
    train_transform = [

        A.HorizontalFlip(p=0.5),

        A.ShiftScaleRotate(scale_limit=0.6, rotate_limit=0, shift_limit=0.1, p=1, border_mode=0),

        A.PadIfNeeded(min_height=height, min_width=width, always_apply=True, border_mode=0,value=1),
        A.RandomCrop(height=height, width=width, always_apply=True),

        A.GaussNoise(p=0.2),
        A.Perspective(p=0.5),

        A.OneOf(
            [
                A.CLAHE(p=1),
                A.RandomBrightnessContrast(p=1),
                A.RandomGamma(p=1),
            ],
            p=0.9,
        ),

        A.OneOf(
            [
                A.Sharpen(p=1),
                A.Blur(blur_limit=3, p=1),
                A.MotionBlur(blur_limit=3, p=1),
            ],
            p=0.9,
        ),

        A.OneOf(
            [
                A.RandomBrightnessContrast(p=1),
                A.HueSaturationValue(p=1),
            ],
            p=0.9,
        ),
        A.Lambda(mask=round_clip_0_1)
    ]
    return A.Compose(train_transform)


def get_validation_augmentation(height, width):
    """Add paddings to make image shape divisible by 32"""
    test_transform = [
        #A.PadIfNeeded(height, width),
        A.Resize(height, width, always_apply=True)
    ]
    return A.Compose(test_transform)

def data_get_preprocessing(preprocessing_fn):
    """Construct preprocessing transform
    
    Args:
        preprocessing_fn (callbale): data normalization function 
            (can be specific for each pretrained neural network)
    Return:
        transform: albumentations.Compose
    
    """
    
    _transform = [
        A.Lambda(image=preprocessing_fn),
    ]
    return A.Compose(_transform)

# %% [markdown]
# ### Define some global variables

# %%
###########Asi deberia de ser###############
#Total_classes = ['Rocks','Terrain','People','Building','Robot','Sky','Trees','Station S','WhatEver']
#N_total_classes = 9
############################################
Total_classes = ['rocks','station','background']
N_total_classes = 3

#Classes_pixel_count_dict = {"Rocks":346,'Terrain':818301,'People':15709988,'Building':140525,'Robot':250492,
#                            'Sky':807478,'Trees':4485973,'Station S':2201037,'WhatEver':2733,'noKnow':123848,
#                            'noKnow2':35279}

Classes_pixel_count_dict = {'rocks':620848,'station':56432,'background':17754720}



MODEL_CLASSES = Total_classes
ALL_CLASSES = False
if MODEL_CLASSES == Total_classes:
    ALL_CLASSES = True

batch_size = 2
N_classes = len(Total_classes)
#HEIGHT = 480
#WIDTH = 640
HEIGHT = 240
WIDTH = 320
backbone_name = "efficientnetb1"
weights = "imagenet"
wwo_aug = True # train data with and without augmentation

# %% [markdown]
# ### Functions to calculate appropriate class weights

# %%
################################################################################
# Class Weights
################################################################################
def get_dataset_counts(d):
    pixel_count = np.array([i for i in d.values()])

    sum_pixel_count = 0
    for i in pixel_count:
        sum_pixel_count += i

    return pixel_count, sum_pixel_count

def get_dataset_statistics(pixel_count, sum_pixel_count):
    
    pixel_frequency = np.round(pixel_count / sum_pixel_count, 4)

    mean_pixel_frequency = np.round(np.mean(pixel_frequency), 4)

    return pixel_frequency, mean_pixel_frequency

def get_balancing_class_weights(classes, d):
    pixel_count, sum_pixel_count = get_dataset_counts(d)

    background_pixel_count = 0
    mod_pixel_count = []

    for c in Total_classes:
        if c not in classes:
            background_pixel_count += d[c]
        else:
            mod_pixel_count.append(d[c])

    if not ALL_CLASSES:
        mod_pixel_count.append(background_pixel_count)
    else:
        mod_pixel_count[:-1]
    
    pixel_frequency, mean_pixel_frequency = get_dataset_statistics(mod_pixel_count, sum_pixel_count)

    class_weights = np.round(mean_pixel_frequency / pixel_frequency, 2)
    return class_weights    

class_weights = get_balancing_class_weights(MODEL_CLASSES, Classes_pixel_count_dict)
print(class_weights)
# Out:
# [  9.89 107.55   0.35]

# %% [markdown]
# ### Data Generation Functions

# %%
################################################################################
# Data Generator
################################################################################
def create_image_label_path_generator(images_dir, masks_dir, shuffle=False, seed=None):
    ids = sorted(os.listdir(images_dir))
    mask_ids = sorted(os.listdir(masks_dir))

    if shuffle == True:

        if seed is not None:
            tf.random.set_seed(seed)

        indices = tf.range(start=0, limit=tf.shape(ids)[0], dtype=tf.int32)
        shuffled_indices = tf.random.shuffle(indices)

        ids = tf.gather(ids, shuffled_indices).numpy().astype(str)
        mask_ids = tf.gather(mask_ids, shuffled_indices).numpy().astype(str)

    images_fps = [os.path.join(images_dir, image_id) for image_id in ids]
    masks_fps = [os.path.join(masks_dir, image_id) for image_id in mask_ids]

    while True:
        for i in range(len(images_fps)):
            yield [images_fps[i], masks_fps[i]]


def process_image_label(images_paths, masks_paths, classes, augmentation=None, preprocessing=None, all_classes=False):
    class_values = [Total_classes.index(cls.lower()) for cls in classes]
    #print(class_values)
    class_values = [1,2,3]
    
    # read data
    image = cv2.imread(images_paths)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    mask = cv2.imread(masks_paths, 0)
    #print(mask)

    # extract certain classes from mask (e.g. cars)
    masks = [(mask == v) for v in class_values]
    #print(masks)
    mask = np.stack(masks, axis=-1).astype('float')
    #print(mask)
    
    # add background if mask is not binary
    if mask.shape[-1] != 1 and not all_classes:
        background = 1 - mask.sum(axis=-1, keepdims=True)
        mask = np.concatenate((mask, background), axis=-1)
    
    # apply augmentations
    if augmentation:
        sample = augmentation(image=image, mask=mask)
        image, mask = sample['image'], sample['mask']
    
    # apply preprocessing
    if preprocessing:
        sample = preprocessing(image=image, mask=mask)
        image, mask = sample['image'], sample['mask']

    # mask = np.squeeze(np.argmax(mask, axis=-1))
    # mask = np.argmax(mask, axis=-1)
    # mask = mask[..., np.newaxis]
        
    return image, mask

def DataGenerator(train_dir, label_dir, batch_size, height, width, classes, augmentation, all_classes=False, wwo_aug=False, shuffle=False, seed=None):
    image_label_path_generator = create_image_label_path_generator(
        train_dir, label_dir, shuffle=shuffle, seed=seed
    )
    if wwo_aug:
        while True:
            images = np.zeros(shape=[batch_size, height, width, 3])
            if all_classes:
                labels = np.zeros(shape=[batch_size, height, width, len(classes)], dtype=np.float32)
            else:
                labels = np.zeros(shape=[batch_size, height, width, len(classes) + 1], dtype=np.float32)
            for i in range(0, batch_size, 2):
                image_path, label_path = next(image_label_path_generator)
                image_aug, label_aug = process_image_label(image_path, label_path, classes=classes, augmentation=augmentation, all_classes=all_classes)
                image_wo_aug, label_wo_aug = process_image_label(image_path, label_path, classes=classes, augmentation=get_validation_augmentation(height=HEIGHT, width=WIDTH), all_classes=all_classes)
                images[i], labels[i] = image_aug, label_aug
                images[i + 1], labels[i + 1] = image_wo_aug, label_wo_aug

            yield tf.convert_to_tensor(images), tf.convert_to_tensor(labels, tf.float32)
    else:
        while True:
            images = np.zeros(shape=[batch_size, height, width, 3])
            if all_classes:
                labels = np.zeros(shape=[batch_size, height, width, len(classes)], dtype=np.float32)
            else:
                labels = np.zeros(shape=[batch_size, height, width, len(classes) + 1], dtype=np.float32)
            for i in range(batch_size):
                image_path, label_path = next(image_label_path_generator)
                image, label = process_image_label(image_path, label_path, classes=classes, augmentation=augmentation, all_classes=all_classes)
                images[i], labels[i] = image, label

            yield tf.convert_to_tensor(images), tf.convert_to_tensor(labels, tf.float32)

# %% [markdown]
# ### Create the Model

# %%
base_model, layers, layer_names = tasm.create_base_model(name=backbone_name, weights=weights, height=HEIGHT, width=WIDTH, include_top=False, pooling=None)

BACKBONE_TRAINABLE = False
model = tasm.DANet(n_classes=N_classes, base_model=base_model, output_layers=layers, backbone_trainable=BACKBONE_TRAINABLE)

# %% [markdown]
# ### Define the optimizer as well as losses, metrics and callbacks

# %%
opt = tf.keras.optimizers.SGD(learning_rate=0.2, momentum=0.9)
metrics = [tasm.metrics.IOUScore(threshold=0.5)]
categorical_focal_dice_loss = tasm.losses.CategoricalFocalLoss(alpha=0.25, gamma=2.0) + tasm.losses.DiceLoss(class_weights=class_weights)

model.compile(
    optimizer=opt,
    loss=categorical_focal_dice_loss,
    metrics=metrics,
)
model.run_eagerly = True
#Colab
#path_model_save = "/content/drive/MyDrive/modelos_segmentacion".
#Super pc universidad
#path_model_save = "C:/Users/Imagine/Documents/Robocol_vision/TresClases_Ordenado/modelo/"
path_model_save = "C:/Users/Imagine/Documents/Robocol_vision/TresClases_Ordenado/modelo1/"

callbacks = [
             tf.keras.callbacks.ModelCheckpoint(path_model_save, verbose=1, save_weights_only=True, save_best_only=True),
             tf.keras.callbacks.ReduceLROnPlateau(monitor="iou_score", factor=0.2, patience=6, verbose=1, mode="max"),
             tf.keras.callbacks.EarlyStopping(monitor="iou_score", patience=16, mode="max", verbose=1, restore_best_weights=True)
]

# %% [markdown]
# ### Get the Data

# %%
train_shuffle = True
val_shuffle = True
seed = 29598

#TrainSetwwoAug = DataGenerator(
#    x_train_dir,
#    y_train_dir,
#    batch_size,
#    HEIGHT,
#    WIDTH,
#    classes=MODEL_CLASSES,
#    augmentation=get_training_augmentation(height=HEIGHT, width=WIDTH),
#    all_classes=ALL_CLASSES,
#    wwo_aug=True,
#    shuffle=train_shuffle,
#    seed=seed
#)

TrainSetwoAug = DataGenerator(
    x_train_dir,
    y_train_dir,
    batch_size,
    HEIGHT,
    WIDTH,
    classes=MODEL_CLASSES,
    augmentation=get_validation_augmentation(height=HEIGHT, width=WIDTH),
    shuffle=train_shuffle,
    all_classes = True,
    seed=seed
)

ValidationSet = DataGenerator(
    x_valid_dir,
    y_valid_dir,
    1,
    HEIGHT,
    WIDTH,
    classes=MODEL_CLASSES,
    augmentation=get_validation_augmentation(height=HEIGHT, width=WIDTH),
    all_classes=ALL_CLASSES,
    shuffle=val_shuffle,
    seed=seed
)

TestSet = DataGenerator(
    x_test_dir,
    y_test_dir,
    1,
    HEIGHT,
    WIDTH,
    classes=MODEL_CLASSES,
    augmentation=get_validation_augmentation(height=HEIGHT, width=WIDTH),
    all_classes=ALL_CLASSES,
    shuffle=False
)

cont=0
for i in TrainSetwoAug:
    sample_image, sample_mask = i[0][0], i[1][0]
    print(len(i))
    print(i[0].shape)
    print(i[1].shape)
    
    #print(cont)
    #print(np.unique(sample_mask))
    #cont+=1
    break

print(len(os.listdir(x_train_dir)))
print(len(os.listdir(x_valid_dir)))
print(len(os.listdir(x_test_dir)))

#sample_mask = sample_mask[:,:,:3]
# Out:
# 2
# (2, 240, 320, 3)
# (2, 240, 320, 3)
# 4800
# 600
# 600

# %%
def display(display_list):
    plt.figure(figsize=(15, 15))

    title = ['Input Image', 'True Mask', 'Predicted Mask']

    for i in range(len(display_list)):
        plt.subplot(1, len(display_list), i+1)
        plt.title(title[i])
        plt.imshow(tf.keras.preprocessing.image.array_to_img(display_list[i]))
        plt.axis('off')
    plt.show()

def create_mask(pred_mask):
    
    pred_mask = tf.argmax(pred_mask, axis=-1)
    pred_mask = pred_mask[..., tf.newaxis]
    return pred_mask[0]

def show_predictions(dataset=None, num=1):
    output_model = model(sample_image[tf.newaxis, ...])
    # print(output_model.numpy())
    
    output_mask = create_mask(output_model)
    # print(sample_mask.shape)

    scce = tf.keras.losses.CategoricalCrossentropy()
    print("SparseCategoricalCrossentroy: " + str(scce(sample_mask, output_model[0]).numpy()))
    # print(iou_score(sample_mask, output_model[0]))
    print("Iou-Score: " + str(tasm.losses.iou_score(sample_mask[tf.newaxis, ...], output_model, class_weights=class_weights).numpy()))
    # print("Dice Loss: " + str(dice_loss(sample_mask, output_model[0]).numpy()))
    # print("Categorical Focal Loss: " + str(categorical_focal_loss(sample_mask, output_model[0]).numpy()))
    print("categorical Focal Dice Loss: " + str(categorical_focal_dice_loss(sample_mask[tf.newaxis, ...], output_model).numpy()))
    
    display([sample_image, tf.argmax(sample_mask, axis=-1)[..., tf.newaxis], output_mask]) # K.one_hot(K.squeeze(output_mask, axis=-1), 3)])
    
show_predictions()
# Out:
# SparseCategoricalCrossentroy: 1.2347984
# Iou-Score: 0.12686682
# categorical Focal Dice Loss: 0.82292646

# %%
for layer in model.layers:
    if "model" in layer.name:
        layer.trainable = False

    print(layer.name + ": " + str(layer.trainable))
# Out:
# up_sampling2d_1: True
# model_1: False
# convolution_bn_activation_11: True
# convolution_bn_activation_12: True
# pam__module_1: True
# cam__module_1: True
# convolution_bn_activation_16: True
# convolution_bn_activation_17: True
# dropout_3: True
# dropout_4: True
# dropout_5: True
# convolution_bn_activation_18: True
# convolution_bn_activation_19: True
# convolution_bn_activation_20: True
# concatenate_4: True
# concatenate_5: True
# convolution_bn_activation_21: True

# %%
if wwo_aug:
    steps_per_epoch = np.floor(len(os.listdir(x_train_dir)) / batch_size) * 2
else:
    steps_per_epoch = np.floor(len(os.listdir(x_train_dir)) / batch_size)

history = model.fit(
    TrainSetwoAug,
    #steps_per_epoch=steps_per_epoch,
    steps_per_epoch = 2400,
    epochs=100,
    callbacks=callbacks,
    validation_data=ValidationSet,
    validation_steps=len(os.listdir(x_valid_dir))
    )
# Out:
# Epoch 1/100
# 2400/2400 [==============================] - 960s 400ms/step - loss: -17.9199 - iou_score: 0.4746 - val_loss: -21.6381 - val_iou_score: 0.5721
#
# Epoch 00001: val_loss improved from inf to -21.63811, saving model to C:/Users/Imagine/Documents/Robocol_vision/TresClases_Ordenado/modelo1\
# Epoch 2/100
# 2400/2400 [==============================] - 968s 403ms/step - loss: -20.8734 - iou_score: 0.5224 - val_loss: -21.8785 - val_iou_score: 0.5695
#
# Epoch 00002: val_loss improved from -21.63811 to -21.87848, saving model to C:/Users/Imagine/Documents/Robocol_vision/TresClases_Ordenado/modelo1\
# Epoch 3/100
# 2400/2400 [==============================] - 969s 404ms/step - loss: -21.1385 - iou_score: 0.5536 - val_loss: -21.9141 - val_iou_score: 0.5761
#
# Epoch 00003: val_loss improved from -21.87848 to -21.91414, saving model to C:/Users/Imagine/Documents/Robocol_vision/TresClases_Ordenado/modelo1\
# Epoch 4/100
# 2400/2400 [==============================] - 970s 404ms/step - loss: -21.1346 - iou_score: 0.5538 - val_loss: -21.9461 - val_iou_score: 0.5884
#
# Epoch 00004: val_loss improved from -21.91414 to -21.94608, saving model to C:/Users/Imagine/Documents/Robocol_vision/TresClases_Ordenado/modelo1\
# Epoch 5/100
# 2400/2400 [==============================] - 969s 404ms/step - loss: -21.2699 - iou_score: 0.5698 - val_loss: -21.9424 - val_iou_score: 0.5786
#
# Epoch 00005: val_loss did not improve from -21.94608
# Epoch 6/100
# 2400/2400 [==============================] - 968s 403ms/step - loss: -21.3834 - iou_score: 0.5819 - val_loss: -21.9443 - val_iou_score: 0.5985
#
# Epoch 00006: val_loss did not improve from -21.94608
# Epoch 7/100
# 2400/2400 [==============================] - 970s 404ms/step - loss: -21.4255 - iou_score: 0.5860 - val_loss: -22.0232 - val_iou_score: 0.5827
#
# Epoch 00007: val_loss improved from -21.94608 to -22.02319, saving model to C:/Users/Imagine/Documents/Robocol_vision/TresClases_Ordenado/modelo1\
# Epoch 8/100
# 2400/2400 [==============================] - 971s 405ms/step - loss: -21.4714 - iou_score: 0.5909 - val_loss: -22.1910 - val_iou_score: 0.6057
#
# Epoch 00008: val_loss improved from -22.02319 to -22.19099, saving model to C:/Users/Imagine/Documents/Robocol_vision/TresClases_Ordenado/modelo1\
# Epoch 9/100
# 2400/2400 [==============================] - 970s 404ms/step - loss: -21.5169 - iou_score: 0.5970 - val_loss: -22.2656 - val_iou_score: 0.6199
#
# Epoch 00009: val_loss improved from -22.19099 to -22.26558, saving model to C:/Users/Imagine/Documents/Robocol_vision/TresClases_Ordenado/modelo1\
# Epoch 10/100
# 2400/2400 [==============================] - 970s 404ms/step - loss: -21.5384 - iou_score: 0.5976 - val_loss: -22.1725 - val_iou_score: 0.6040
#
# Epoch 00010: val_loss did not improve from -22.26558
# Epoch 11/100
# 2400/2400 [==============================] - 971s 404ms/step - loss: -21.5199 - iou_score: 0.5953 - val_loss: -22.3075 - val_iou_score: 0.6191
#
# Epoch 00011: val_loss improved from -22.26558 to -22.30746, saving model to C:/Users/Imagine/Documents/Robocol_vision/TresClases_Ordenado/modelo1\
# Epoch 12/100
# 2400/2400 [==============================] - 970s 404ms/step - loss: -21.5333 - iou_score: 0.5982 - val_loss: -22.1826 - val_iou_score: 0.6195
#
# Epoch 00012: val_loss did not improve from -22.30746
# Epoch 13/100
# 2400/2400 [==============================] - 971s 405ms/step - loss: -21.5711 - iou_score: 0.6023 - val_loss: -22.2970 - val_iou_score: 0.6187
#
# Epoch 00013: val_loss did not improve from -22.30746
# Epoch 14/100
# 2400/2400 [==============================] - 972s 405ms/step - loss: -21.4485 - iou_score: 0.5883 - val_loss: -22.1161 - val_iou_score: 0.6265
#
# Epoch 00014: val_loss did not improve from -22.30746
# Epoch 15/100
# 2400/2400 [==============================] - 971s 405ms/step - loss: -21.6435 - iou_score: 0.6099 - val_loss: -22.3366 - val_iou_score: 0.6209
#
# Epoch 00015: val_loss improved from -22.30746 to -22.33657, saving model to C:/Users/Imagine/Documents/Robocol_vision/TresClases_Ordenado/modelo1\
# Epoch 16/100
# 2400/2400 [==============================] - 972s 405ms/step - loss: -21.6304 - iou_score: 0.6082 - val_loss: -22.4346 - val_iou_score: 0.6391
#
# Epoch 00016: val_loss improved from -22.33657 to -22.43459, saving model to C:/Users/Imagine/Documents/Robocol_vision/TresClases_Ordenado/modelo1\
# Epoch 17/100
# 2400/2400 [==============================] - 972s 405ms/step - loss: -21.6488 - iou_score: 0.6112 - val_loss: -22.4459 - val_iou_score: 0.6468
#
# Epoch 00017: val_loss improved from -22.43459 to -22.44593, saving model to C:/Users/Imagine/Documents/Robocol_vision/TresClases_Ordenado/modelo1\
# Epoch 18/100
# 2400/2400 [==============================] - 973s 405ms/step - loss: -21.6721 - iou_score: 0.6147 - val_loss: -22.3724 - val_iou_score: 0.6301
#
# Epoch 00018: val_loss did not improve from -22.44593
# Epoch 19/100
# 2400/2400 [==============================] - 974s 406ms/step - loss: -21.6437 - iou_score: 0.6109 - val_loss: -22.3044 - val_iou_score: 0.6345
#
# Epoch 00019: val_loss did not improve from -22.44593
# Epoch 20/100
# 2400/2400 [==============================] - 975s 406ms/step - loss: -21.5485 - iou_score: 0.6008 - val_loss: -22.3687 - val_iou_score: 0.6267
#
# Epoch 00020: val_loss did not improve from -22.44593
# Epoch 21/100
# 2400/2400 [==============================] - 975s 406ms/step - loss: -21.7253 - iou_score: 0.6206 - val_loss: -22.4880 - val_iou_score: 0.6421
#
# Epoch 00021: val_loss improved from -22.44593 to -22.48797, saving model to C:/Users/Imagine/Documents/Robocol_vision/TresClases_Ordenado/modelo1\
# Epoch 22/100
# 2400/2400 [==============================] - 972s 405ms/step - loss: -21.7438 - iou_score: 0.6222 - val_loss: -22.4753 - val_iou_score: 0.6534
#
# Epoch 00022: val_loss did not improve from -22.48797
# Epoch 23/100
# 2400/2400 [==============================] - 974s 406ms/step - loss: -21.7585 - iou_score: 0.6244 - val_loss: -21.1275 - val_iou_score: 0.5435
#
# Epoch 00023: val_loss did not improve from -22.48797
# Epoch 24/100
# 2400/2400 [==============================] - 975s 406ms/step - loss: -21.0526 - iou_score: 0.5448 - val_loss: -22.4371 - val_iou_score: 0.6400
#
# Epoch 00024: val_loss did not improve from -22.48797
# Epoch 25/100
# 2400/2400 [==============================] - 976s 407ms/step - loss: -21.7532 - iou_score: 0.6240 - val_loss: -22.5363 - val_iou_score: 0.6541
#
# Epoch 00025: val_loss improved from -22.48797 to -22.53634, saving model to C:/Users/Imagine/Documents/Robocol_vision/TresClases_Ordenado/modelo1\
# Epoch 26/100
# 2400/2400 [==============================] - 977s 407ms/step - loss: -21.7412 - iou_score: 0.6222 - val_loss: -22.1578 - val_iou_score: 0.5990
#
# Epoch 00026: val_loss did not improve from -22.53634
# Epoch 27/100
# 2400/2400 [==============================] - 977s 407ms/step - loss: -21.7511 - iou_score: 0.6227 - val_loss: -22.4381 - val_iou_score: 0.6411
#
# Epoch 00027: val_loss did not improve from -22.53634
# Epoch 28/100
# 2400/2400 [==============================] - 976s 407ms/step - loss: -21.7195 - iou_score: 0.6189 - val_loss: -22.0912 - val_iou_score: 0.6032
#
# Epoch 00028: val_loss did not improve from -22.53634
# Epoch 29/100
# 2400/2400 [==============================] - 977s 407ms/step - loss: -21.4945 - iou_score: 0.5929 - val_loss: -22.3625 - val_iou_score: 0.6329
#
# Epoch 00029: val_loss did not improve from -22.53634
# Epoch 30/100
# 2400/2400 [==============================] - 977s 407ms/step - loss: -21.5953 - iou_score: 0.6050 - val_loss: -22.3715 - val_iou_score: 0.6311
#
# Epoch 00030: val_loss did not improve from -22.53634
# Epoch 31/100
# 2400/2400 [==============================] - 979s 408ms/step - loss: -21.5252 - iou_score: 0.5966 - val_loss: -21.2943 - val_iou_score: 0.4931
#
# Epoch 00031: val_loss did not improve from -22.53634
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.04000000059604645.
# Epoch 32/100
# 2400/2400 [==============================] - 980s 408ms/step - loss: -20.7152 - iou_score: 0.4857 - val_loss: -21.4251 - val_iou_score: 0.5176
#
# Epoch 00032: val_loss did not improve from -22.53634
# Epoch 33/100
# 2400/2400 [==============================] - 980s 408ms/step - loss: -20.8500 - iou_score: 0.5168 - val_loss: -22.0807 - val_iou_score: 0.5970
#
# Epoch 00033: val_loss did not improve from -22.53634
# Epoch 34/100
# 2400/2400 [==============================] - 981s 409ms/step - loss: -21.5428 - iou_score: 0.5963 - val_loss: -22.4552 - val_iou_score: 0.6439
#
# Epoch 00034: val_loss did not improve from -22.53634
# Epoch 35/100
# 2400/2400 [==============================] - 982s 409ms/step - loss: -21.7487 - iou_score: 0.6227 - val_loss: -22.4965 - val_iou_score: 0.6482
#
# Epoch 00035: val_loss did not improve from -22.53634
# Epoch 36/100
# 2400/2400 [==============================] - 985s 410ms/step - loss: -21.7795 - iou_score: 0.6261 - val_loss: -22.5179 - val_iou_score: 0.6512
#
# Epoch 00036: val_loss did not improve from -22.53634
# Epoch 37/100
# 2400/2400 [==============================] - 983s 410ms/step - loss: -21.7742 - iou_score: 0.6261 - val_loss: -22.3615 - val_iou_score: 0.6311
#
# Epoch 00037: val_loss did not improve from -22.53634
# Epoch 38/100
# 2400/2400 [==============================] - 984s 410ms/step - loss: -21.8222 - iou_score: 0.6317 - val_loss: -22.5343 - val_iou_score: 0.6541
#
# Epoch 00038: val_loss did not improve from -22.53634
# Epoch 39/100
# 2400/2400 [==============================] - 984s 410ms/step - loss: -21.4658 - iou_score: 0.5948 - val_loss: -22.4157 - val_iou_score: 0.6468
#
# Epoch 00039: val_loss did not improve from -22.53634
# Epoch 40/100
# 2400/2400 [==============================] - 985s 410ms/step - loss: -21.8217 - iou_score: 0.6321 - val_loss: -22.4898 - val_iou_score: 0.6525
#
# Epoch 00040: val_loss did not improve from -22.53634
# Epoch 41/100
# 2400/2400 [==============================] - 986s 411ms/step - loss: -21.8361 - iou_score: 0.6338 - val_loss: -22.5515 - val_iou_score: 0.6544
#
# Epoch 00041: val_loss improved from -22.53634 to -22.55150, saving model to C:/Users/Imagine/Documents/Robocol_vision/TresClases_Ordenado/modelo1\
# Epoch 42/100
# 2400/2400 [==============================] - 988s 412ms/step - loss: -21.8601 - iou_score: 0.6374 - val_loss: -22.5118 - val_iou_score: 0.6541
#
# Epoch 00042: val_loss did not improve from -22.55150
# Epoch 43/100
# 2400/2400 [==============================] - 988s 412ms/step - loss: -21.8705 - iou_score: 0.6387 - val_loss: -22.5499 - val_iou_score: 0.6576
#
# Epoch 00043: val_loss did not improve from -22.55150
# Epoch 44/100
# 2400/2400 [==============================] - 988s 412ms/step - loss: -21.8599 - iou_score: 0.6387 - val_loss: -22.5350 - val_iou_score: 0.6553
#
# Epoch 00044: val_loss did not improve from -22.55150
# Epoch 45/100
# 2400/2400 [==============================] - 989s 412ms/step - loss: -21.8820 - iou_score: 0.6388 - val_loss: -22.5684 - val_iou_score: 0.6601
#
# Epoch 00045: val_loss improved from -22.55150 to -22.56845, saving model to C:/Users/Imagine/Documents/Robocol_vision/TresClases_Ordenado/modelo1\
# Epoch 46/100
# 2400/2400 [==============================] - 994s 414ms/step - loss: -21.8806 - iou_score: 0.6402 - val_loss: -22.5628 - val_iou_score: 0.6577
#
# Epoch 00046: val_loss did not improve from -22.56845
# Epoch 47/100
# 2400/2400 [==============================] - 991s 413ms/step - loss: -21.8928 - iou_score: 0.6417 - val_loss: -22.1683 - val_iou_score: 0.6309
#
# Epoch 00047: val_loss did not improve from -22.56845
# Epoch 48/100
# 2400/2400 [==============================] - 992s 413ms/step - loss: -21.9085 - iou_score: 0.6432 - val_loss: -21.3527 - val_iou_score: 0.5433
#
# Epoch 00048: val_loss did not improve from -22.56845
# Epoch 49/100
# 2400/2400 [==============================] - 988s 412ms/step - loss: -21.5303 - iou_score: 0.5998 - val_loss: -22.5688 - val_iou_score: 0.6572
#
# Epoch 00049: val_loss improved from -22.56845 to -22.56881, saving model to C:/Users/Imagine/Documents/Robocol_vision/TresClases_Ordenado/modelo1\
# Epoch 50/100
# 2400/2400 [==============================] - 983s 410ms/step - loss: -21.9037 - iou_score: 0.6415 - val_loss: -22.5797 - val_iou_score: 0.6645
#
# Epoch 00050: val_loss improved from -22.56881 to -22.57966, saving model to C:/Users/Imagine/Documents/Robocol_vision/TresClases_Ordenado/modelo1\
# Epoch 51/100
# 2400/2400 [==============================] - 991s 413ms/step - loss: -21.8917 - iou_score: 0.6416 - val_loss: -22.5750 - val_iou_score: 0.6690
#
# Epoch 00051: val_loss did not improve from -22.57966
# Epoch 52/100
# 2400/2400 [==============================] - 995s 415ms/step - loss: -21.9013 - iou_score: 0.6436 - val_loss: -22.6019 - val_iou_score: 0.6636
#
# Epoch 00052: val_loss improved from -22.57966 to -22.60185, saving model to C:/Users/Imagine/Documents/Robocol_vision/TresClases_Ordenado/modelo1\
# Epoch 53/100
# 2400/2400 [==============================] - 996s 415ms/step - loss: -21.9217 - iou_score: 0.6468 - val_loss: -22.5666 - val_iou_score: 0.6556
#
# Epoch 00053: val_loss did not improve from -22.60185
# Epoch 54/100
# 2400/2400 [==============================] - 996s 415ms/step - loss: -21.9284 - iou_score: 0.6460 - val_loss: -22.6052 - val_iou_score: 0.6649
#
# Epoch 00054: val_loss improved from -22.60185 to -22.60522, saving model to C:/Users/Imagine/Documents/Robocol_vision/TresClases_Ordenado/modelo1\
# Epoch 55/100
# 2400/2400 [==============================] - 998s 416ms/step - loss: -21.9361 - iou_score: 0.6476 - val_loss: -22.5840 - val_iou_score: 0.6593
#
# Epoch 00055: val_loss did not improve from -22.60522
# Epoch 56/100
# 2400/2400 [==============================] - 998s 416ms/step - loss: -21.9160 - iou_score: 0.6447 - val_loss: -22.3025 - val_iou_score: 0.6229
#
# Epoch 00056: val_loss did not improve from -22.60522
# Epoch 57/100
# 2400/2400 [==============================] - 998s 416ms/step - loss: -21.8911 - iou_score: 0.6424 - val_loss: -22.4337 - val_iou_score: 0.6396
#
# Epoch 00057: val_loss did not improve from -22.60522
# Epoch 58/100
# 2400/2400 [==============================] - 999s 416ms/step - loss: -21.9083 - iou_score: 0.6442 - val_loss: -22.4573 - val_iou_score: 0.6562
#
# Epoch 00058: val_loss did not improve from -22.60522
# Epoch 59/100
# 2400/2400 [==============================] - 1000s 417ms/step - loss: -21.9342 - iou_score: 0.6475 - val_loss: -22.5154 - val_iou_score: 0.6544
#
# Epoch 00059: val_loss did not improve from -22.60522
# Epoch 60/100
# 2400/2400 [==============================] - 1001s 417ms/step - loss: -21.9026 - iou_score: 0.6431 - val_loss: -22.5748 - val_iou_score: 0.6580
#
# Epoch 00060: val_loss did not improve from -22.60522
# Epoch 61/100
# 2400/2400 [==============================] - 954s 397ms/step - loss: -21.8924 - iou_score: 0.6412 - val_loss: -22.3967 - val_iou_score: 0.6338
#
# Epoch 00061: val_loss did not improve from -22.60522
#
# Epoch 00061: ReduceLROnPlateau reducing learning rate to 0.007999999821186066.
# Epoch 62/100
# 2400/2400 [==============================] - 948s 395ms/step - loss: -21.9561 - iou_score: 0.6480 - val_loss: -22.6148 - val_iou_score: 0.6655
#
# Epoch 00062: val_loss improved from -22.60522 to -22.61476, saving model to C:/Users/Imagine/Documents/Robocol_vision/TresClases_Ordenado/modelo1\
# Epoch 63/100
# 2400/2400 [==============================] - 962s 401ms/step - loss: -21.9714 - iou_score: 0.6511 - val_loss: -22.6165 - val_iou_score: 0.6667
#
# Epoch 00063: val_loss improved from -22.61476 to -22.61650, saving model to C:/Users/Imagine/Documents/Robocol_vision/TresClases_Ordenado/modelo1\
# Epoch 64/100
# 2400/2400 [==============================] - 954s 397ms/step - loss: -21.9825 - iou_score: 0.6530 - val_loss: -22.6081 - val_iou_score: 0.6694
#
# Epoch 00064: val_loss did not improve from -22.61650
# Epoch 65/100
# 2400/2400 [==============================] - 951s 396ms/step - loss: -21.9910 - iou_score: 0.6548 - val_loss: -22.6208 - val_iou_score: 0.6680
#
# Epoch 00065: val_loss improved from -22.61650 to -22.62081, saving model to C:/Users/Imagine/Documents/Robocol_vision/TresClases_Ordenado/modelo1\
# Epoch 66/100
# 2400/2400 [==============================] - 951s 396ms/step - loss: -21.9904 - iou_score: 0.6534 - val_loss: -22.6310 - val_iou_score: 0.6687
#
# Epoch 00066: val_loss improved from -22.62081 to -22.63095, saving model to C:/Users/Imagine/Documents/Robocol_vision/TresClases_Ordenado/modelo1\
# Epoch 67/100
# 2400/2400 [==============================] - 957s 399ms/step - loss: -21.9953 - iou_score: 0.6553 - val_loss: -22.6218 - val_iou_score: 0.6675
#
# Epoch 00067: val_loss did not improve from -22.63095
# Epoch 68/100
# 2400/2400 [==============================] - 953s 397ms/step - loss: -21.9932 - iou_score: 0.6547 - val_loss: -22.6344 - val_iou_score: 0.6709
#
# Epoch 00068: val_loss improved from -22.63095 to -22.63437, saving model to C:/Users/Imagine/Documents/Robocol_vision/TresClases_Ordenado/modelo1\
# Epoch 69/100
# 2400/2400 [==============================] - 953s 397ms/step - loss: -22.0013 - iou_score: 0.6562 - val_loss: -22.6339 - val_iou_score: 0.6689
#
# Epoch 00069: val_loss did not improve from -22.63437
# Epoch 70/100
# 2400/2400 [==============================] - 952s 397ms/step - loss: -22.0073 - iou_score: 0.6566 - val_loss: -22.6222 - val_iou_score: 0.6668
#
# Epoch 00070: val_loss did not improve from -22.63437
# Epoch 71/100
# 2400/2400 [==============================] - 952s 397ms/step - loss: -22.0059 - iou_score: 0.6562 - val_loss: -22.6368 - val_iou_score: 0.6699
#
# Epoch 00071: val_loss improved from -22.63437 to -22.63682, saving model to C:/Users/Imagine/Documents/Robocol_vision/TresClases_Ordenado/modelo1\
# Epoch 72/100
# 2400/2400 [==============================] - 953s 397ms/step - loss: -22.0027 - iou_score: 0.6562 - val_loss: -22.6337 - val_iou_score: 0.6700
#
# Epoch 00072: val_loss did not improve from -22.63682
# Epoch 73/100
# 2400/2400 [==============================] - 953s 397ms/step - loss: -22.0074 - iou_score: 0.6561 - val_loss: -22.6383 - val_iou_score: 0.6664
#
# Epoch 00073: val_loss improved from -22.63682 to -22.63829, saving model to C:/Users/Imagine/Documents/Robocol_vision/TresClases_Ordenado/modelo1\
# Epoch 74/100
# 2400/2400 [==============================] - 953s 397ms/step - loss: -22.0126 - iou_score: 0.6567 - val_loss: -22.6264 - val_iou_score: 0.6626
#
# Epoch 00074: val_loss did not improve from -22.63829
# Epoch 75/100
# 2400/2400 [==============================] - 953s 397ms/step - loss: -22.0128 - iou_score: 0.6566 - val_loss: -22.6434 - val_iou_score: 0.6733
#
# Epoch 00075: val_loss improved from -22.63829 to -22.64345, saving model to C:/Users/Imagine/Documents/Robocol_vision/TresClases_Ordenado/modelo1\
# Epoch 76/100
# 2400/2400 [==============================] - 953s 397ms/step - loss: -22.0126 - iou_score: 0.6568 - val_loss: -22.6322 - val_iou_score: 0.6697
#
# Epoch 00076: val_loss did not improve from -22.64345
# Epoch 77/100
# 2400/2400 [==============================] - 953s 397ms/step - loss: -22.0185 - iou_score: 0.6587 - val_loss: -22.6448 - val_iou_score: 0.6708
#
# Epoch 00077: val_loss improved from -22.64345 to -22.64484, saving model to C:/Users/Imagine/Documents/Robocol_vision/TresClases_Ordenado/modelo1\
# Epoch 78/100
# 2400/2400 [==============================] - 953s 397ms/step - loss: -22.0192 - iou_score: 0.6579 - val_loss: -22.6365 - val_iou_score: 0.6680
#
# Epoch 00078: val_loss did not improve from -22.64484
# Epoch 79/100
# 2400/2400 [==============================] - 953s 397ms/step - loss: -22.0209 - iou_score: 0.6572 - val_loss: -22.6447 - val_iou_score: 0.6672
#
# Epoch 00079: val_loss did not improve from -22.64484
# Epoch 80/100
# 2400/2400 [==============================] - 955s 398ms/step - loss: -22.0260 - iou_score: 0.6584 - val_loss: -22.6530 - val_iou_score: 0.6709
#
# Epoch 00080: val_loss improved from -22.64484 to -22.65302, saving model to C:/Users/Imagine/Documents/Robocol_vision/TresClases_Ordenado/modelo1\
# Epoch 81/100
# 2400/2400 [==============================] - 955s 398ms/step - loss: -22.0279 - iou_score: 0.6596 - val_loss: -22.6520 - val_iou_score: 0.6719
#
# Epoch 00081: val_loss did not improve from -22.65302
# Epoch 82/100
# 2400/2400 [==============================] - 955s 398ms/step - loss: -22.0237 - iou_score: 0.6588 - val_loss: -22.6557 - val_iou_score: 0.6716
#
# Epoch 00082: val_loss improved from -22.65302 to -22.65566, saving model to C:/Users/Imagine/Documents/Robocol_vision/TresClases_Ordenado/modelo1\
# Epoch 83/100
# 2400/2400 [==============================] - 956s 398ms/step - loss: -22.0287 - iou_score: 0.6595 - val_loss: -22.6526 - val_iou_score: 0.6710
#
# Epoch 00083: val_loss did not improve from -22.65566
# Epoch 84/100
# 2400/2400 [==============================] - 957s 399ms/step - loss: -22.0292 - iou_score: 0.6596 - val_loss: -22.6356 - val_iou_score: 0.6692
#
# Epoch 00084: val_loss did not improve from -22.65566
# Epoch 85/100
# 2400/2400 [==============================] - 959s 400ms/step - loss: -22.0372 - iou_score: 0.6607 - val_loss: -22.6405 - val_iou_score: 0.6698
#
# Epoch 00085: val_loss did not improve from -22.65566
# Epoch 86/100
# 2400/2400 [==============================] - 964s 402ms/step - loss: -22.0387 - iou_score: 0.6610 - val_loss: -22.6580 - val_iou_score: 0.6710
#
# Epoch 00086: val_loss improved from -22.65566 to -22.65799, saving model to C:/Users/Imagine/Documents/Robocol_vision/TresClases_Ordenado/modelo1\
# Epoch 87/100
# 2400/2400 [==============================] - 960s 400ms/step - loss: -22.0417 - iou_score: 0.6613 - val_loss: -22.6492 - val_iou_score: 0.6727
#
# Epoch 00087: val_loss did not improve from -22.65799
# Epoch 88/100
# 2400/2400 [==============================] - 966s 402ms/step - loss: -22.0365 - iou_score: 0.6610 - val_loss: -22.6574 - val_iou_score: 0.6739
#
# Epoch 00088: val_loss did not improve from -22.65799
# Epoch 89/100
# 2400/2400 [==============================] - 962s 401ms/step - loss: -22.0362 - iou_score: 0.6610 - val_loss: -22.6594 - val_iou_score: 0.6706
#
# Epoch 00089: val_loss improved from -22.65799 to -22.65938, saving model to C:/Users/Imagine/Documents/Robocol_vision/TresClases_Ordenado/modelo1\
# Epoch 90/100
# 2400/2400 [==============================] - 964s 402ms/step - loss: -22.0405 - iou_score: 0.6608 - val_loss: -22.6594 - val_iou_score: 0.6716
#
# Epoch 00090: val_loss improved from -22.65938 to -22.65942, saving model to C:/Users/Imagine/Documents/Robocol_vision/TresClases_Ordenado/modelo1\
# Epoch 91/100
# 2400/2400 [==============================] - 965s 402ms/step - loss: -22.0417 - iou_score: 0.6610 - val_loss: -22.6497 - val_iou_score: 0.6720
#
# Epoch 00091: val_loss did not improve from -22.65942
# Epoch 92/100
# 2400/2400 [==============================] - 965s 402ms/step - loss: -22.0472 - iou_score: 0.6631 - val_loss: -22.6549 - val_iou_score: 0.6715
#
# Epoch 00092: val_loss did not improve from -22.65942
# Epoch 93/100
# 2400/2400 [==============================] - 974s 406ms/step - loss: -22.0529 - iou_score: 0.6621 - val_loss: -22.6622 - val_iou_score: 0.6736
#
# Epoch 00093: val_loss improved from -22.65942 to -22.66215, saving model to C:/Users/Imagine/Documents/Robocol_vision/TresClases_Ordenado/modelo1\
# Epoch 94/100
# 2400/2400 [==============================] - 971s 404ms/step - loss: -22.0550 - iou_score: 0.6628 - val_loss: -22.6608 - val_iou_score: 0.6708
#
# Epoch 00094: val_loss did not improve from -22.66215
# Epoch 95/100
# 2400/2400 [==============================] - 971s 405ms/step - loss: -22.0479 - iou_score: 0.6615 - val_loss: -22.6640 - val_iou_score: 0.6735
#
# Epoch 00095: val_loss improved from -22.66215 to -22.66401, saving model to C:/Users/Imagine/Documents/Robocol_vision/TresClases_Ordenado/modelo1\
# Epoch 96/100
# 2400/2400 [==============================] - 974s 406ms/step - loss: -22.0540 - iou_score: 0.6635 - val_loss: -22.6676 - val_iou_score: 0.6753
#
# Epoch 00096: val_loss improved from -22.66401 to -22.66757, saving model to C:/Users/Imagine/Documents/Robocol_vision/TresClases_Ordenado/modelo1\
# Epoch 97/100
# 2400/2400 [==============================] - 973s 406ms/step - loss: -22.0536 - iou_score: 0.6644 - val_loss: -22.6527 - val_iou_score: 0.6696
#
# Epoch 00097: val_loss did not improve from -22.66757
# Epoch 98/100
# 2400/2400 [==============================] - 974s 406ms/step - loss: -22.0564 - iou_score: 0.6654 - val_loss: -22.6684 - val_iou_score: 0.6733
#
# Epoch 00098: val_loss improved from -22.66757 to -22.66842, saving model to C:/Users/Imagine/Documents/Robocol_vision/TresClases_Ordenado/modelo1\
# Epoch 99/100
# 2400/2400 [==============================] - 976s 406ms/step - loss: -22.0560 - iou_score: 0.6641 - val_loss: -22.6704 - val_iou_score: 0.6763
#
# Epoch 00099: val_loss improved from -22.66842 to -22.67045, saving model to C:/Users/Imagine/Documents/Robocol_vision/TresClases_Ordenado/modelo1\
# Epoch 100/100
# 2400/2400 [==============================] - 977s 407ms/step - loss: -22.0591 - iou_score: 0.6640 - val_loss: -22.6668 - val_iou_score: 0.6730
#
# Epoch 00100: val_loss did not improve from -22.67045

# %%
plt.figure(figsize=(30, 5))
plt.subplot(121)
plt.plot(history.history['iou_score'])
# plt.plot(history.history['val_iou_score'])
plt.title('Model IOU Score')
plt.ylabel('IOU Score')
plt.xlabel('Epoch')
plt.legend(['Train'], loc='upper left')

# Plot training & validation loss values
plt.subplot(122)
plt.plot(history.history['loss'])
# plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train'], loc='upper left')
plt.show()

# %% [markdown]
# ### Evaluation on test Data

# %%
scores = model.evaluate(TestSet, steps=101)

print("Loss: {:.5}".format(scores[0]))
for metric, value in zip(metrics, scores[1:]):
    if metric != "accuracy":
        metric = metric.__name__
    print("mean {}: {:.5}".format(metric, value))
# Out:
# 101/101 [==============================] - 10s 103ms/step - loss: -21.8699 - iou_score: 0.6714
# Loss: -21.87
# mean iou_score: 0.67141

# %%
n = 5
ids = np.random.choice(np.arange(101), size=n,replace=False)
print(ids)

counter = 0
second_counter = 0
for i in TestSet:
    if counter in ids:
        image, gt_mask = i
        # image = np.expand_dims(image, axis=0)
        pr_mask = model.predict(image)
        pr_mask = np.argmax(pr_mask, axis=-1)

        print(counter)
        
        visualize(
            image=denormalize(image.numpy().squeeze()),
            gt_mask=gt_mask.numpy().squeeze(),
            pr_mask=pr_mask.squeeze(),
        )
        second_counter += 1
    counter += 1
    if second_counter == n:
        break
# Out:
# [33  0 19 36 92]
# 0
# 19
# 33
# 36
# 92

# %%
path_save_h5 = "C:/Users/Imagine/Documents/Robocol_vision/TresClases_Ordenado/modelo_h5"
model.save(path_save_h5)
# Out:
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.merge.Concatenate object at 0x000001EFC4564880>, because it is not built.
# WARNING:absl:Found untraced functions such as activation_13_layer_call_and_return_conditional_losses, activation_13_layer_call_fn, conv2d_11_layer_call_and_return_conditional_losses, conv2d_11_layer_call_fn, activation_14_layer_call_and_return_conditional_losses while saving (showing 5 of 135). These functions will not be directly callable after loading.
# WARNING:absl:Found untraced functions such as activation_13_layer_call_and_return_conditional_losses, activation_13_layer_call_fn, conv2d_11_layer_call_and_return_conditional_losses, conv2d_11_layer_call_fn, activation_14_layer_call_and_return_conditional_losses while saving (showing 5 of 135). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:/Users/Imagine/Documents/Robocol_vision/TresClases_Ordenado/modelo_h5\assets
# INFO:tensorflow:Assets written to: C:/Users/Imagine/Documents/Robocol_vision/TresClases_Ordenado/modelo_h5\assets
